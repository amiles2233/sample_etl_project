# %%
import pandas as pd
from sqlalchemy import create_engine
import numpy as np

# %%
challenger = pd.read_csv("challenger_match_data.csv", index_col=0)

# %%
challenger_players = challenger.groupby(["gameId"]).size().reset_index(name = 'n_challengers')
challenger_players
# Out:
#            gameId  n_challengers
# 0      4083343388              1
# 1      4083362752              1
# 2      4083389656              1
# 3      4083401236              1
# 4      4083456764              1
# ...           ...            ...
# 12646  4261001693              4
# 12647  4261012162              4
# 12648  4261013083              1
# 12649  4261020773              7
# 12650  4261025558              9
#
# [12651 rows x 2 columns]

# %%
match = pd.read_csv("match_data_version1.csv", index_col=0)

# %%
match_trim = match.loc[:,["gameId", "gameMode", "gameType", "seasonId"]].drop_duplicates()

# %%
match_trim
# Out:
#           gameId gameMode      gameType  seasonId
# 0   4.247263e+09  CLASSIC  MATCHED_GAME      13.0
# 1   4.247156e+09  CLASSIC  MATCHED_GAME      13.0
# 2   4.243963e+09  CLASSIC  MATCHED_GAME      13.0
# 3   4.241678e+09  CLASSIC  MATCHED_GAME      13.0
# 4   4.241539e+09  CLASSIC  MATCHED_GAME      13.0
# ..           ...      ...           ...       ...
# 0   4.088497e+09      URF  MATCHED_GAME      13.0
# 0   4.130964e+09  CLASSIC  MATCHED_GAME      13.0
# 0   4.119954e+09  CLASSIC  MATCHED_GAME      13.0
# 0   4.130440e+09      URF  MATCHED_GAME      13.0
# 0   4.225861e+09     ARAM  MATCHED_GAME      13.0
#
# [108773 rows x 4 columns]

# %%
winner = pd.read_csv("match_winner_data_version1.csv", index_col = 0)
winner.head()
winner_trim = winner[["gameId", "firstBlood", "firstTower", "towerKills"]].drop_duplicates()
winner_named = winner_trim.rename(columns = {"firstBlood": "winnerFirstBlood", "firstTower": "winnerFirstTower", "towerKills": "winnerTowerKills"})
winner_named
# Out:
#               gameId  winnerFirstBlood  winnerFirstTower  winnerTowerKills
# 0       4.247263e+09             False              True                 9
# 1       4.247156e+09             False             False                 4
# 2       4.243963e+09              True              True                 5
# 3       4.241678e+09              True              True                 6
# 4       4.241539e+09              True              True                11
# ...              ...               ...               ...               ...
# 108824  4.088497e+09             False              True                 9
# 108825  4.130964e+09              True             False                 5
# 108826  4.119954e+09             False             False                 6
# 108827  4.130440e+09              True              True                10
# 108828  4.225861e+09             False              True                 4
#
# [108773 rows x 4 columns]

# %%
loser = pd.read_csv("match_loser_data_version1.csv", index_col = 0)
loser.head()
loser_trim = loser[["gameId", "firstBlood", "firstTower", "towerKills"]].drop_duplicates()
loser_named = loser_trim.rename(columns = {"firstBlood": "loserFirstBlood", "firstTower": "loserFirstTower", "towerKills": "loserTowerKills"})
loser_named
# Out:
#               gameId  loserFirstBlood  loserFirstTower  loserTowerKills
# 0       4.247263e+09             True            False                0
# 1       4.247156e+09             True             True                2
# 2       4.243963e+09            False            False                0
# 3       4.241678e+09            False            False                2
# 4       4.241539e+09            False            False                6
# ...              ...              ...              ...              ...
# 108824  4.088497e+09             True            False                3
# 108825  4.130964e+09            False             True                3
# 108826  4.119954e+09             True             True                6
# 108827  4.130440e+09            False            False                5
# 108828  4.225861e+09             True            False                4
#
# [108773 rows x 4 columns]

# %%
match_merged = match_trim.merge(winner_named, on = "gameId", how="left")\
    .merge(loser_named, on="gameId", how="left")\
    .merge(challenger_players, on="gameId", how="left")
match_merged
# Out:
#               gameId gameMode      gameType  seasonId  winnerFirstBlood  \
# 0       4.247263e+09  CLASSIC  MATCHED_GAME      13.0             False
# 1       4.247156e+09  CLASSIC  MATCHED_GAME      13.0             False
# 2       4.243963e+09  CLASSIC  MATCHED_GAME      13.0              True
# 3       4.241678e+09  CLASSIC  MATCHED_GAME      13.0              True
# 4       4.241539e+09  CLASSIC  MATCHED_GAME      13.0              True
# ...              ...      ...           ...       ...               ...
# 108768  4.088497e+09      URF  MATCHED_GAME      13.0             False
# 108769  4.130964e+09  CLASSIC  MATCHED_GAME      13.0              True
# 108770  4.119954e+09  CLASSIC  MATCHED_GAME      13.0             False
# 108771  4.130440e+09      URF  MATCHED_GAME      13.0              True
# 108772  4.225861e+09     ARAM  MATCHED_GAME      13.0             False
#
#         winnerFirstTower  winnerTowerKills  loserFirstBlood  loserFirstTower  \
# 0                   True                 9             True            False
# 1                  False                 4             True             True
# 2                   True                 5            False            False
# 3                   True                 6            False            False
# 4                   True                11            False            False
# ...                  ...               ...              ...              ...
# 108768              True                 9             True            False
# 108769             False                 5            False             True
# 108770             False                 6             True             True
# 108771              True                10            False            False
# 108772              True                 4             True            False
#
#         loserTowerKills  n_challengers
# 0                     0           10.0
# 1                     2           10.0
# 2                     0           10.0
# 3                     2            8.0
# 4                     6           10.0
# ...                 ...            ...
# 108768                3            NaN
# 108769                3            NaN
# 108770                6            NaN
# 108771                5            NaN
# 108772                4            NaN
#
# [108773 rows x 11 columns]

# %%
# Replace NA challengers with 0
match_merged['n_challengers'] = match_merged['n_challengers'].fillna(0)

# Convert Booleans to 1 or 0
match_merged['winnerFirstBlood'] = match_merged['winnerFirstBlood']*1
match_merged['winnerFirstTower'] = match_merged['winnerFirstTower']*1
match_merged['loserFirstBlood'] = match_merged['loserFirstBlood']*1
match_merged['loserFirstTower'] = match_merged['loserFirstTower']*1

# Convert GameID to Integer
match_merged["gameId"].astype(int)

match_merged = match_merged.reset_index(drop=True).set_index(["gameId"])

match_merged.head()
# Out:
#              gameMode      gameType  seasonId  winnerFirstBlood  \
# gameId
# 4.247263e+09  CLASSIC  MATCHED_GAME      13.0                 0
# 4.247156e+09  CLASSIC  MATCHED_GAME      13.0                 0
# 4.243963e+09  CLASSIC  MATCHED_GAME      13.0                 1
# 4.241678e+09  CLASSIC  MATCHED_GAME      13.0                 1
# 4.241539e+09  CLASSIC  MATCHED_GAME      13.0                 1
#
#               winnerFirstTower  winnerTowerKills  loserFirstBlood  \
# gameId
# 4.247263e+09                 1                 9                1
# 4.247156e+09                 0                 4                1
# 4.243963e+09                 1                 5                0
# 4.241678e+09                 1                 6                0
# 4.241539e+09                 1                11                0
#
#               loserFirstTower  loserTowerKills  n_challengers
# gameId
# 4.247263e+09                0                0           10.0
# 4.247156e+09                1                2           10.0
# 4.243963e+09                0                0           10.0
# 4.241678e+09                0                2            8.0
# 4.241539e+09                0                6           10.0

# %% [markdown]
# ### Connect to Database

# %%
rds_connection_string = "postgres:postgres@localhost:5432/league_of_legends"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %% [markdown]
# ### Copy Local File to Database

# %%
engine.table_names()
# Out:
# ['match_features']

# %%
match_merged.to_sql(name='match_features', con=engine, if_exists='append', index=True)
# Out:
# ---------------------------------------------------------------------------
# NotNullViolation                          Traceback (most recent call last)
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1263                     self.dialect.do_executemany(
# -> 1264                         cursor, statement, parameters, context
#    1265                     )
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     872         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 873             cursor.executemany(statement, parameters)
#     874             return
#
# NotNullViolation: null value in column "ID" violates not-null constraint
# DETAIL:  Failing row contains (null, 4247263043, CLASSIC, MATCHED_GAME, 13.0, 0, 1, 9, 1, 0, 0, 10).
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-96-85ecf13d4c53> in <module>
# ----> 1 match_merged.to_sql(name='match_features', con=engine, if_exists='append', index=False)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2661             chunksize=chunksize,
#    2662             dtype=dtype,
# -> 2663             method=method,
#    2664         )
#    2665
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     519         chunksize=chunksize,
#     520         dtype=dtype,
# --> 521         method=method,
#     522     )
#     523
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1315         )
#    1316         table.create()
# -> 1317         table.insert(chunksize, method=method)
#    1318         if not name.isdigit() and not name.islower():
#    1319             # check for potentially case sensitivity issues (GH7815)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     753
#     754                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 755                 exec_insert(conn, keys, chunk_iter)
#     756
#     757     def _query_iterator(
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     667         """
#     668         data = [dict(zip(keys, row)) for row in data_iter]
# --> 669         conn.execute(self.table.insert(), data)
#     670
#     671     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#    1018             )
#    1019         else:
# -> 1020             return meth(self, multiparams, params)
#    1021
#    1022     def _execute_function(self, func, multiparams, params):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     296     def _execute_on_connection(self, connection, multiparams, params):
#     297         if self.supports_execution:
# --> 298             return connection._execute_clauseelement(self, multiparams, params)
#     299         else:
#     300             raise exc.ObjectNotExecutableError(self)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1137             distilled_params,
#    1138             compiled_sql,
# -> 1139             distilled_params,
#    1140         )
#    1141         if self._has_events or self.engine._has_events:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1322         except BaseException as e:
#    1323             self._handle_dbapi_exception(
# -> 1324                 e, statement, parameters, cursor, context
#    1325             )
#    1326
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1516             elif should_wrap:
#    1517                 util.raise_(
# -> 1518                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1519                 )
#    1520             else:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1262                 if not evt_handled:
#    1263                     self.dialect.do_executemany(
# -> 1264                         cursor, statement, parameters, context
#    1265                     )
#    1266             elif not parameters and context.no_parameters:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     871     def do_executemany(self, cursor, statement, parameters, context=None):
#     872         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 873             cursor.executemany(statement, parameters)
#     874             return
#     875
#
# IntegrityError: (psycopg2.errors.NotNullViolation) null value in column "ID" violates not-null constraint
# DETAIL:  Failing row contains (null, 4247263043, CLASSIC, MATCHED_GAME, 13.0, 0, 1, 9, 1, 0, 0, 10).
#
# [SQL: INSERT INTO match_features ("gameId", "gameMode", "gameType", "seasonId", "winnerFirstBlood", "winnerFirstTower", "winnerTowerKills", "loserFirstBlood", "loserFirstTower", "loserTowerKills", n_challengers) VALUES (%(gameId)s, %(gameMode)s, %(gameType)s, %(seasonId)s, %(winnerFirstBlood)s, %(winnerFirstTower)s, %(winnerTowerKills)s, %(loserFirstBlood)s, %(loserFirstTower)s, %(loserTowerKills)s, %(n_challengers)s)]
# [parameters: ({'gameId': 4247263043.0, 'gameMode': 'CLASSIC', 'gameType': 'MATCHED_GAME', 'seasonId': 13.0, 'winnerFirstBlood': 0, 'winnerFirstTower': 1, 'winnerTowerKills': 9, 'loserFirstBlood': 1, 'loserFirstTower': 0, 'loserTowerKills': 0, 'n_challengers': 10.0}, {'gameId': 4247155821.0, 'gameMode': 'CLASSIC', 'gameType': 'MATCHED_GAME', 'seasonId': 13.0, 'winnerFirstBlood': 0, 'winnerFirstTower': 0, 'winnerTowerKills': 4, 'loserFirstBlood': 1, 'loserFirstTower': 1, 'loserTowerKills': 2, 'n_challengers': 10.0}, {'gameId': 4243963257.0, 'gameMode': 'CLASSIC', 'gameType': 'MATCHED_GAME', 'seasonId': 13.0, 'winnerFirstBlood': 1, 'winnerFirstTower': 1, 'winnerTowerKills': 5, 'loserFirstBlood': 0, 'loserFirstTower': 0, 'loserTowerKills': 0, 'n_challengers': 10.0}, {'gameId': 4241678498.0, 'gameMode': 'CLASSIC', 'gameType': 'MATCHED_GAME', 'seasonId': 13.0, 'winnerFirstBlood': 1, 'winnerFirstTower': 1, 'winnerTowerKills': 6, 'loserFirstBlood': 0, 'loserFirstTower': 0, 'loserTowerKills': 2, 'n_challengers': 8.0}, {'gameId': 4241538868.0, 'gameMode': 'CLASSIC', 'gameType': 'MATCHED_GAME', 'seasonId': 13.0, 'winnerFirstBlood': 1, 'winnerFirstTower': 1, 'winnerTowerKills': 11, 'loserFirstBlood': 0, 'loserFirstTower': 0, 'loserTowerKills': 6, 'n_challengers': 10.0}, {'gameId': 4241394461.0, 'gameMode': 'CLASSIC', 'gameType': 'MATCHED_GAME', 'seasonId': 13.0, 'winnerFirstBlood': 1, 'winnerFirstTower': 1, 'winnerTowerKills': 8, 'loserFirstBlood': 0, 'loserFirstTower': 0, 'loserTowerKills': 2, 'n_challengers': 10.0}, {'gameId': 4233222221.0, 'gameMode': 'CLASSIC', 'gameType': 'MATCHED_GAME', 'seasonId': 13.0, 'winnerFirstBlood': 1, 'winnerFirstTower': 0, 'winnerTowerKills': 7, 'loserFirstBlood': 0, 'loserFirstTower': 1, 'loserTowerKills': 2, 'n_challengers': 8.0}, {'gameId': 4233113995.0, 'gameMode': 'CLASSIC', 'gameType': 'MATCHED_GAME', 'seasonId': 13.0, 'winnerFirstBlood': 1, 'winnerFirstTower': 1, 'winnerTowerKills': 10, 'loserFirstBlood': 0, 'loserFirstTower': 0, 'loserTowerKills': 1, 'n_challengers': 5.0}  ... displaying 10 of 108773 total bound parameter sets ...  {'gameId': 4130440172.0, 'gameMode': 'URF', 'gameType': 'MATCHED_GAME', 'seasonId': 13.0, 'winnerFirstBlood': 1, 'winnerFirstTower': 1, 'winnerTowerKills': 10, 'loserFirstBlood': 0, 'loserFirstTower': 0, 'loserTowerKills': 5, 'n_challengers': 0.0}, {'gameId': 4225860590.0, 'gameMode': 'ARAM', 'gameType': 'MATCHED_GAME', 'seasonId': 13.0, 'winnerFirstBlood': 0, 'winnerFirstTower': 1, 'winnerTowerKills': 4, 'loserFirstBlood': 1, 'loserFirstTower': 0, 'loserTowerKills': 4, 'n_challengers': 0.0})]
# (Background on this error at: http://sqlalche.me/e/gkpj)
